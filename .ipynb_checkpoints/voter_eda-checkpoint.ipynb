# %%
import os, json, glob
import pandas as pd
from pandas import ExcelFile
import numpy as np

# %%
with open("cols.json") as cols_file:
    column_names = json.load(cols_file)['cols']
print len(column_names)
# Out:
# 43

# %%
cols = ['ID','last_name','first_name','gender','house_number','street','apartment_number','zip','council_district']
f = 'Philly Voter List 3.xlsx'
to_str = lambda x: str(x)
df = pd.read_excel(f,header=None, nrows=10,names=cols, usecols=[0,2,3,6,12,14,15,19,38],converters={'house_number':to_str,'zip':to_str})

# %%
df['short_address'] = df['house_number'].astype(str) + df['street']

# %%
df['house_number']
# Out:
# 0          526.0
# 1         1702.0
# 2         1121.0
# 3          723.0
# 4         1401.0
# 5          250.0
# 6          145.0
# 7         1003.0
# 8          222.0
# 9          709.0
# 10         644.0
# 11         816.0
# 12         437.0
# 13         615.0
# 14        1433.0
# 15         814.0
# 16        1512.0
# 17         839.0
# 18         236.0
# 19        1311.0
# 20        1533.0
# 21         704.0
# 22        1611.0
# 23        1524.0
# 24        1415.0
# 25         434.0
# 26        1413.0
# 27         507.0
# 28         917.0
# 29         430.0
#           ...
# 49970      425.0
# 49971    10204.0
# 49972     2701.0
# 49973    12407.0
# 49974     3870.0
# 49975    10733.0
# 49976    12209.0
# 49977     3750.0
# 49978     3750.0
# 49979    12209.0
# 49980     9923.0
# 49981    11921.0
# 49982    10923.0
# 49983     4165.0
# 49984     3721.0
# 49985     3517.0
# 49986     3501.0
# 49987     9951.0
# 49988     3750.0
# 49989      189.0
# 49990    10922.0
# 49991     2958.0
# 49992    11843.0
# 49993     4257.0
# 49994    11713.0
# 49995     3643.0
# 49996    12242.0
# 49997     3400.0
# 49998    12018.0
# 49999        NaN
# Name: house_number, dtype: float64

# %%
allFiles = glob.glob("Philly*.xlsx")
frame = pd.DataFrame()
list_ = []
#cols = ['first_name','last_name','gender','council_district','house_number','street','zip']
for file_ in allFiles:
    df = pd.read_excel(file_,index_col=0, header=None, names=column_names, usecols=range(0,44))
    list_.append(df)
frame = pd.concat(list_)

# %%
fairhill = frame.loc[frame['zip']==19133]

fairhill.to_csv('fairhill.csv',encoding='utf-8')

# %%
properties = pd.read_csv('../opa_properties_public.csv',usecols=['location','owner_1','owner_2','lat','lng'])

# %%
fairhill['location'] = fairhill['house_number'].astype(str) + " " + fairhill['street']
# Out:
# C:\Users\catst\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
geocoded_voters = pd.merge(fairhill,properties,how='left',on='location')

# %%
len(geocoded_voters) - len(geocoded_voters.loc[geocoded_voters['lat'].isnull()])
# Out:
# 9759

# %%
frame = frame[['unknown1','last_name','suffix','affiliation','unknown2','street','state','cg']]

# %%
frame.columns = ['last_name','first_name','gender','house_number','street','apartment_number','zip','council_district']

# %%
focus_districts = frame[(frame['council_district'] == "CTC03") | (frame['council_district'] == "CTC08") | (frame['council_district'] == "CTC09")]

focus_districts.to_json('focus_districts.json',orient="records")

focus_districts = focus_districts.set_index('ID')

len(focus_districts)
# Out:
# 322125

# %%
evictions = pd.read_csv("merged_1990.csv")
# Out:
# C:\Users\catst\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
evictions.head()
# Out:
#    Unnamed: 0                id                          premises_x  \
# 0           0  LT-06-11-01-3209  6901 OLD YORK RD, PHILADELPHIA, PA
# 1           1  LT-94-06-16-1577  220 W LUZERNE ST, PHILADELPHIA, PA
# 2           2  LT-06-12-29-7247   6038 OGONTZ AVE, PHILADELPHIA, PA
# 3           4  LT-94-09-16-1407     128 S 56TH ST, PHILADELPHIA, PA
# 4           5  LT-94-12-21-1995   1516 JUDSON WAY, PHILADELPHIA, PA
#
#          lat        lon number        street          city state    zip  \
# 0  40.058737 -75.138612   6901   Old York Rd  Philadelphia    PA  19126
# 1  40.011256 -75.130653    220  W Luzerne St  Philadelphia    PA  19140
# 2  40.047536 -75.151097   6038    Ogontz Ave  Philadelphia    PA  19141
# 3  39.957997 -75.233559    128     S 56th St  Philadelphia    PA  19139
# 4  39.978381 -75.173388   1516    Judson Way  Philadelphia    PA  19121
#
#      ...    jba_breach  non_residential  unaware months publichousing  \
# 0    ...             f                f        f    1.0             f
# 1    ...             f                f        f    NaN             f
# 2    ...             f                f        f    0.0             f
# 3    ...             f                f        f    NaN             f
# 4    ...             f                f        f    NaN             f
#
#   first_hearing_dow latitude longitude clean_address firstname
# 0               1.0      NaN       NaN           NaN       NaN
# 1               4.0      NaN       NaN           NaN       NaN
# 2               2.0      NaN       NaN           NaN       NaN
# 3               2.0      NaN       NaN           NaN       NaN
# 4               3.0      NaN       NaN           NaN       NaN
#
# [5 rows x 91 columns]

# %%
evictions['defendant'] = evictions['defendant'].str.upper()
evictions['voter_record'] = ""

# %%
focus_districts.iloc[0]
# Out:
# unknown1                                      NaN
# last_name                                    HILL
# first_name                                      R
# middle_initial                                  C
# suffix                                        NaN
# gender                                          M
# birth_date                    1972-04-23 00:00:00
# date_registered               1997-03-17 00:00:00
# affiliated                                      I
# affilitation_date             2017-01-19 00:00:00
# affiliation                                     D
# house_number                                 5922
# unknown2                                      NaN
# street                                  IRVING ST
# apartment_number                              NaN
# address2                                      NaN
# city                                 PHILADELPHIA
# state                                          PA
# zip                                         19139
# unk3                                          NaN
# unk4                                          NaN
# unk5                                          NaN
# unk6                                          NaN
# unk7                                          NaN
# last_voted                    2008-11-04 00:00:00
# polling_place                                 307
# polling_place_subdivision                  0307-1
# unk_date                      2011-02-02 00:00:00
# unk_num_string                        2.30538e+10
# polling_place_2                               307
# ward                                         WD03
# unk8                                          NaN
# mn                                           MN01
# unk9                                          NaN
# lg                                          LG191
# sn                                           SN08
# cg                                           CG01
# council_district                            CTC03
# cpr                                           CPR
# cpd                                           CPD
# rcd                                         RCD01
# polling_place_subdivision2                 0307-1
# Name: 015920096-51, dtype: object

# %%
for idx, voter in focus_districts.sample(frac=.01).iterrows():
    first = voter['first_name']
    last = voter['last_name']
    voter_id = idx
    mask = (evictions['defendant'].str.contains(first)) & (evictions['defendant'].str.contains(last))
    evictions['voter_record'] = evictions['voter_record'].mask(mask,voter_id)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-77b407008283> in <module>()
#       3     last = voter['last_name']
#       4     voter_id = idx
# ----> 5     mask = (evictions['defendant'].str.contains(first)) & (evictions['defendant'].str.contains(last))
#       6     evictions['voter_record'] = evictions['voter_record'].mask(mask,voter_id)
#
# C:\Users\catst\Anaconda2\lib\site-packages\pandas\core\strings.pyc in contains(self, pat, case, flags, na, regex)
#    1469     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    1470         result = str_contains(self._data, pat, case=case, flags=flags, na=na,
# -> 1471                               regex=regex)
#    1472         return self._wrap_result(result)
#    1473
#
# C:\Users\catst\Anaconda2\lib\site-packages\pandas\core\strings.pyc in str_contains(arr, pat, case, flags, na, regex)
#     245             uppered = _na_map(lambda x: x.upper(), arr)
#     246             return _na_map(f, uppered, na, dtype=bool)
# --> 247     return _na_map(f, arr, na, dtype=bool)
#     248
#     249
#
# C:\Users\catst\Anaconda2\lib\site-packages\pandas\core\strings.pyc in _na_map(f, arr, na_result, dtype)
#     145 def _na_map(f, arr, na_result=np.nan, dtype=object):
#     146     # should really _check_ for NA
# --> 147     return _map(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     148
#     149
#
# C:\Users\catst\Anaconda2\lib\site-packages\pandas\core\strings.pyc in _map(f, arr, na_mask, na_value, dtype)
#     161         mask = isnull(arr)
#     162         try:
# --> 163             result = lib.map_infer_mask(arr, f, mask.view(np.uint8))
#     164         except (TypeError, AttributeError):
#     165
#
# pandas\src\inference.pyx in pandas.lib.map_infer_mask (pandas\lib.c:62228)()
#
# C:\Users\catst\Anaconda2\lib\site-packages\pandas\core\strings.pyc in <lambda>(x)
#     236                           stacklevel=3)
#     237
# --> 238         f = lambda x: bool(regex.search(x))
#     239     else:
#     240         if case:
#
# KeyboardInterrupt:

# %%
matched = evictions.loc[evictions['voter_record'] != ""]

# %%
matched.to_json('evicted_voters.json',orient="records")

# %%
focus_districts.loc[focus_districts.index == '015794249-51'][['first_name', 'last_name','house_number','street','zip']]
# Out:
#              first_name last_name house_number     street    zip
# ID
# 015794249-51     GENEEN     BIBBS         6000  N 13TH ST  19141

# %%
matched[['premises_x','zip','defendant','voter_record']]
# Out:
#                                       premises_x    zip  \
# 182           1903 S JESSUP ST, PHILADELPHIA, PA  19148
# 370            5051 OXFORD AVE, PHILADELPHIA, PA  19124
# 678             3449 N HOPE ST, PHILADELPHIA, PA  19140
# 712            824 E HILTON ST, PHILADELPHIA, PA  19134
# 749         4501 LARCHWOOD AVE, PHILADELPHIA, PA  19143
# 894             1519 LATONA ST, PHILADELPHIA, PA  19146
# 936          5000 WOODBINE AVE, PHILADELPHIA, PA  19131
# 964      2979 W SCHOOLHOUSE LN, PHILADELPHIA, PA  19144
# 1329            1100 S 58TH ST, PHILADELPHIA, PA  19143
# 1475             2711 TITAN ST, PHILADELPHIA, PA  19146
# 1738           3100 WHARTON ST, PHILADELPHIA, PA  19146
# 1825           117 CHESTNUT ST, PHILADELPHIA, PA  19106
# 1827            6350 GREENE ST, PHILADELPHIA, PA  19144
# 1859            931 S PAXON ST, PHILADELPHIA, PA  19143
# 1866    1229 W WESTMORELAND ST, PHILADELPHIA, PA  19140
# 2120        6201 CRITTENDEN ST, PHILADELPHIA, PA  19138
# 2125        5804 LANSDOWNE AVE, PHILADELPHIA, PA  19131
# 2466            1951 S 23RD ST, PHILADELPHIA, PA  19145
# 2659        6060 CRESCENTVL RD, PHILADELPHIA, PA  19120
# 494283                    FRAZIER ROBIN|AND|WILSON RODNEY  014314401-51
# 494311                     JACOBY MICHAEL|AND|SMITH MARIE  103589696-51
# 494920  DAVID E PICKETT|AND|JEFFREY H JORDAN|AND|LISA ...  021870087-51
# 495222    DAVID OTERO|AND|JENNIFER DAVIS|AND|MICHAEL LUPO  015342217-51
# 495322                                       CARTER BRIAN  016194699-51
# 495688  PHILLIPS BARBARA J|AND|PHILLIPS JAMES D|AND|PH...  014593082-51
# 495914                     GERMAINE JONES & ALL OTHER OCC  015571950-51
#
# [2866 rows x 4 columns]

# %%
matched_voter_ids = matched['voter_record']
focus_districts.iloc

# %%
defendant = evictions.iloc[12]['defendant'].upper()
voter = focus_districts.iloc[0]
'ARTHUR' in defendant and 'MCDANIELS' in defendant
# Out:
# True

# %%
test = evictions.sample(frac=.01)
test['voter_record'] = ""
#for i, record in test:
    #test.iat[i,91] = "8237-92"

# %%
test.head()['defendant']
# Out:
# 314598                 FREDERICK WILLIAMS
# 46340     ERIC JONES|AND|JOYCE TODD JONES
# 111571                      MCDOUGALL IAN
# 181511    DEBRA RODGERS|AND|NICOLE GRAHAM
# 494988     MUNN JEANNETT|AND|MUNN PATRICK
# Name: defendant, dtype: object

# %%
first = 'FREDERICK'
last = 'WILLIAMS'
mask = (test['defendant'].str.contains(first)) & (test['defendant'].str.contains(last))
test['voter_record'] = test['voter_record'].mask(mask,"")

# %%
test.head()
# Out:
#         Unnamed: 0                id                               premises_x  \
# 314598      421758  LT-07-05-22-6633         1018 S 48TH ST, PHILADELPHIA, PA
# 46340        61868  LT-03-03-06-0436  6060 CRESCENTVILLE RD, PHILADELPHIA, PA
# 111571      149409  LT-96-03-15-1419         1324 LOCUST ST, PHILADELPHIA, PA
# 181511      243153  LT-08-10-14-5155          233 E PENN ST, PHILADELPHIA, PA
# 494988      663353  LT-95-11-07-0432         2220 WALNUT ST, PHILADELPHIA, PA
#
#               lat        lon number            street          city state  \
# 314598  39.945041 -75.215368   1018         S 48th St  Philadelphia    PA
# 46340   40.041607 -75.114752   6060  Crescentville Rd  Philadelphia    PA
# 111571  39.948065 -75.163382   1324         Locust St  Philadelphia    PA
# 181511  40.034680 -75.166712    233         E Penn St  Philadelphia    PA
# 494988  39.951001 -75.178310   2220         Walnut St  Philadelphia    PA
#
#           zip     ...      non_residential  unaware   months publichousing  \
# 314598  19143     ...                    f        f  4.29274             f
# 46340   19120     ...                    f        f      NaN             f
# 111571  19107     ...                    f        f      NaN             f
# 181511  19144     ...                    f        f  3.00000             f
# 494988  19103     ...                    f        f      NaN             f
#
#        first_hearing_dow latitude longitude clean_address firstname  \
# 314598               5.0      NaN       NaN           NaN       NaN
# 46340                2.0      NaN       NaN           NaN       NaN
# 111571               2.0      NaN       NaN           NaN       NaN
# 181511               4.0      NaN       NaN           NaN       NaN
# 494988               2.0      NaN       NaN           NaN       NaN
#
#        voter_record
# 314598
# 46340
# 111571
# 181511
# 494988
#
# [5 rows x 92 columns]

# %%
len(matched)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a67f122f3221> in <module>()
# ----> 1 len(matched)
#
# NameError: name 'matched' is not defined
